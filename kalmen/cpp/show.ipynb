# %%
import pandas as pd
import matplotlib.pyplot as plt

data1 = pd.read_csv('/media/chen/Data/programme/Visual/SummerStudy/kalmen/source/homework_data_4_.txt', sep=' ', header=None)

data1.columns = ['x', 'y']
plt.scatter(data1['x'], data1['y'], label='y')


data = pd.read_csv('/media/chen/Data/programme/Visual/SummerStudy/kalmen/cpp/output/homework_data_1_output.txt', sep=' ', header=None)
data.columns = ['x', 'y', 'y_p', '']

plt.plot(data1['x'], data['x'], label='y', color = 'red')
#plt.plot(data1['x'], data['y'], label='y')
#plt.plot(data1['x'], data['y_p'], label='y')
